# %% [markdown]
# <a href="https://colab.research.google.com/github/othyTim/Data-for-ML/blob/main/Data_for_ML_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Decribing Data for ML
# Timothy Lingeveldt

# %% [markdown]
# ###Imports

# %%
#Pandas
import pandas as pd

# %% [markdown]
# ##Car Insurance Data

# %% [markdown]
# ###Load describe data

# %%
#Load data
dataset ='/content/drive/MyDrive/CodingDojo/02-MachineLearning/Week08/Data/Car_Insurance_Claim.csv'
df_insurance = pd.read_csv(dataset)

#Describe data
df_insurance.info()
df_insurance.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10000 non-null  int64
#  1   AGE                  10000 non-null  object
#  2   GENDER               10000 non-null  object
#  3   RACE                 10000 non-null  object
#  4   DRIVING_EXPERIENCE   10000 non-null  object
#  5   EDUCATION            10000 non-null  object
#  6   INCOME               10000 non-null  object
#  7   CREDIT_SCORE         9018 non-null   float64
#  8   VEHICLE_OWNERSHIP    10000 non-null  float64
#  9   VEHICLE_YEAR         10000 non-null  object
#  10  MARRIED              10000 non-null  float64
#  11  CHILDREN             10000 non-null  float64
#  12  POSTAL_CODE          10000 non-null  int64
#  13  ANNUAL_MILEAGE       9043 non-null   float64
#  14  VEHICLE_TYPE         10000 non-null  object
# ...

# %% [markdown]
# ###Source of data
#
# FOund on Kaggle. This insurance data was shared by an insurance company - most of data presented is from legitimate customers, howeversome of the data was generated by the sharer.

# %% [markdown]
# ###Description of the data
#
# The data has some basic information about the customer such as gender, income, education, driving experience and so forth. it also has information about the vehicle that is being insured such as mileage, vehicle type, yeat model and so forth.

# %% [markdown]
# ###Target
#
# Y = 'Outcome'

# %% [markdown]
# ###Row One
#
# Row One presents a person who has taken car insurance as well as the infomation of the car being insured

# %% [markdown]
# ###Classification Or Regression
#
# Classification as the goal is predict a binery Target

# %% [markdown]
# ###Features
#
# 18 Features

# %% [markdown]
# ###Row Count
#
# 1000

# %% [markdown]
# ###Challenges do you foresee in cleaning, exploring, or modeling this dataset:
#
# There are a few columns that should be Integer but are object due tp characrers in the fields, such 'age' and 'driving experience'
#
# Irrelevant columns such as 'ID' which will not contribute to the ML models

# %% [markdown]
# ##Adult Income Dataset

# %% [markdown]
# ###Load describe data

# %%
#Load data
dataset ='/content/drive/MyDrive/CodingDojo/02-MachineLearning/Week08/Data/adult.csv'
df_income = pd.read_csv(dataset)

#Describe data
df_income.info()
df_income.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB
# ...

# %% [markdown]
# ###Source of data
#
# The data source is from Kaggle and widely used.

# %% [markdown]
# ###Description of the data
#
# its presents individual's annual income results from various factors such as age, education, gender and so forth.

# %% [markdown]
# ###Target
#
# Y = 'Income'

# %% [markdown]
# ###Row One
#
# Row One presents a person and their personal information(attributes that describes the person) such as marital status, race, relationships, education and so forth

# %% [markdown]
# ###Classification Or Regression
#
# Regression

# %% [markdown]
# ###Features
#
# 14 Features

# %% [markdown]
# ###Row Count
#
# 48842

# %% [markdown]
# ###Challenges do you foresee in cleaning, exploring, or modeling this dataset:
#
# There are missing data and unique charachers such as '?' as well as prefixes in the target coloumn.
# Seems there maybe outliers - 'capital gain' columns
# Many of the features are Categorical whic can impact the model run time to scale the data.
